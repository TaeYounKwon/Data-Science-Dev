# %% [markdown]
# ## 다변수 확률변수

# %% [markdown]
# - 변수가 여러개일 때 분포를 알아보고 연관된 분포 혹은 결과값들을 알아봅시다.
# - 변수가 여러개가 되면 확률분포가 결합되어 결합확률분포함수라고 합니다.
# - 두 개의 확률변수 값의 결합확률분포를 알고 있을 때 두 개 중에 하나의 확률분포를 알고 있으면 나머지 하나의 확률분포도 알 수 있다.

# %% [markdown]
# ### 이산 데이터
#
# - X, Y의 확률질량함수
#       X확률질량함수 = px(x)
#       Y의 확률질량함수 = px(y)
#       결합 확률 질량함수 = pxy(x,y)

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (0.0.1)
# Requirement already satisfied: matplotlib in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from koreanize-matplotlib) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (4.37.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\tempe\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\tempe\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import koreanize_matplotlib
import numpy as np

# 통계 확률  Library
import scipy as sp

# %%
# 영어, 수학
grades = ['A','B','C','D','E','F']
scores = pd.DataFrame(
    [
     [1, 2, 1, 0, 0, 0],
     [0, 2, 3, 1, 0, 0],
     [0, 4, 7, 4, 1, 0],
     [0, 1, 4, 5, 4, 0],
     [0, 0, 1, 3, 2, 0],
     [0, 0, 0, 1, 2, 1]
    ],
    columns = grades, index=grades
)
scores.index.name = '수학'
scores.columns.name = '영어'
scores
# Out:
# 영어  A  B  C  D  E  F
# 수학
# A   1  2  1  0  0  0
# B   0  2  3  1  0  0
# C   0  4  7  4  1  0
# D   0  1  4  5  4  0
# E   0  0  1  3  2  0
# F   0  0  0  1  2  1

# %% [markdown]
# 영어 점수(A~F)를 받았을때 수학(A~F)를 받은 사람 수

# %%
# 총 학생 수
scores.values.sum()
# Out:
# 50

# %%
# 점수를 총 학생 수로 나눠줌
# 결합확률 질량함수 
scores/scores.values.sum()
# Out:
# 영어     A     B     C     D     E     F
# 수학
# A   0.02  0.04  0.02  0.00  0.00  0.00
# B   0.00  0.04  0.06  0.02  0.00  0.00
# C   0.00  0.08  0.14  0.08  0.02  0.00
# D   0.00  0.02  0.08  0.10  0.08  0.00
# E   0.00  0.00  0.02  0.06  0.04  0.00
# F   0.00  0.00  0.00  0.02  0.04  0.02

# %%
pmf = scores/scores.values.sum()
sns.heatmap(pmf, annot=True, cmap=mpl.cm.bone_r, xticklabels=grades, yticklabels=grades)
plt.title("결합확률질량함수 pxy(x,y)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 주변확률질량함수

# %% [markdown]
# 결합확률 질량함수에서 단변수 확률질량함수를 구하는 것
#
# $${px}(x) = \Sigma {pxy}(x,{y_i})$$
#
# $${py}(y) = \Sigma {pxy}({x_i},y)$$
#
#     위의 결합확률질량함수에서 영어의 대한 값을 찾을 때, 영어점수(A~F)에 대한 수학 점수 값을 합한것
#
#     예를 들면, 영어점수(B)는 수학점수 A(0.04) + B(0.04) + C(0.08) + D(0.02) = 0.18
#
#     이런식.

# %%
pmf
# Out:
# 영어     A     B     C     D     E     F
# 수학
# A   0.02  0.04  0.02  0.00  0.00  0.00
# B   0.00  0.04  0.06  0.02  0.00  0.00
# C   0.00  0.08  0.14  0.08  0.02  0.00
# D   0.00  0.02  0.08  0.10  0.08  0.00
# E   0.00  0.00  0.02  0.06  0.04  0.00
# F   0.00  0.00  0.00  0.02  0.04  0.02

# %%
# 확률질량함수
x_english = pmf.sum()
x_english
# Out:
# 영어
# A    0.02
# B    0.18
# C    0.32
# D    0.28
# E    0.18
# F    0.02
# dtype: float64

# %%
y_math = pmf.sum(axis=1)[:,np.newaxis] # [:,np.newaxis] <- 뒤에 시각화를 위해서 수학 확률질량함수를 1D -> 2D로 바꿔줌
# Out:
# C:\Users\tempe\AppData\Local\Temp\ipykernel_3396\116398695.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y_math = pmf.sum(axis=1)[:,np.newaxis] # [:,np.newaxis] <- 뒤에 시각화를 위해서 수학 확률질량함수를 1D -> 2D로 바꿔줌

# %%
y_math
# Out:
# array([[0.08],
#        [0.12],
#        [0.32],
#        [0.28],
#        [0.12],
#        [0.08]])

# %% [markdown]
# ## 조건부확률질량함수

# %% [markdown]
# X,Y 변수 중 하나의 변수가 특정 값으로 고정되는 경우 나머지 하나의 변수의 확률질량함수를 구하는것
#
# $$PX|Y(x|y)=\frac{PXY(x,y)}{PY(y)}$$
#
# $$PY|X(y|x)=\frac{PXY(x,y)}{PX(x)}$$
#
#     수학 점수가 A일때(특정값으로 고정), 영어 점수의 확률질량함수는?
#
#     그냥 수학 점수가 A인 사람의 영어 점수 확률을 보는 것
#
#     위의 그래프의 경우 한줄 한줄 보면 됨

# %%
import string

# A~F까지 대문자의 값을 가지고 올 수 있음
string.ascii_uppercase[:6]
# Out:
# 'ABCDEF'

# %%
grades = ['A','B','C','D','E','F']

x = np.arange(6)
for i, y in enumerate(grades):
  ax = plt.subplot(6, 1, i+1)
  ax.tick_params(labelleft=False)
  plt.bar(x, pmf.iloc[i,:])
  plt.ylabel(f'p(수학={y}, 영어)', rotation=0, labelpad=40)
  plt.ylim(0, 0.15)
  plt.xticks(range(6), grades)

plt.suptitle('수학이 특정 값일 경우 결합질량함수의 단면', y = 1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# 위 그래프의 넓이의 합 = 1

# %%
grades = ['A','B','C','D','E','F']

x = np.arange(6)
for i, y in enumerate(grades):
  ax = plt.subplot(6, 1, i+1)
  ax.tick_params(labelleft=False)
  plt.bar(x, pmf[y])
  plt.ylabel(f'p(영어={y}, 수학)', rotation=0, labelpad=40)
  plt.ylim(0, 0.15)
  plt.xticks(range(6), grades)

plt.suptitle('영어 특정 값일 경우 결합질량함수의 단면', y = 1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 다변수 연속확률 변수

# %% [markdown]
# ### 결합누적확률분포함수
# 이산확률분포처럼 단순사건을 이용할 수 없음(A,B,C,D)
# 키, 몸무게, 속도, 시간, 온도
# Cumulalitive Density Function(CDF) -> 미분 -> Probability Density Function(PDF)
# 결합누적확률분포함수 -> 미분 -> 결합확률밀도함수
#
# $${F_{XY}} = P({X<x, Y<y})$$
#
# - 특성
# $${F_{XY}}(-∞, ∞) = 1$$
# $${F_{XY}}(-∞, y) = {F_{XY}}(x, ∞) = 0$$

# %% [markdown]
# ### 결합확률 밀도 함수
# 결합누적확률분포함수를 미분해서 정의
#
# $${P_{XY}}(x,y)$$
#
# - 특성
#       적분하면 1
# $$ ∫∫{P_{XY}}(x,y)dxdy = 1 $$

# %%
mu = [77, 177] # 몸무게, 키
cov = [
    [150, 140],
    [140, 300]
]
'''
가변수 정규분포를 생성 해 주기 위해서

공분산 행렬 : [
  [분산, 공분산],
  [공분산, 분산]]
]
'''
rv = sp.stats.multivariate_normal(mu, cov)

# linspace => 20~120 중 100개를 동일하게 나눠서 뽑아라
x, y = np.linspace(20, 120, 100), np.linspace(100, 250, 100)

# %%
xm, ym = np.meshgrid(x,y)
z = rv.pdf(np.dstack([xm, ym])) # dstack 은 안의 값이 들어가서 [##, ##]으로 쌓일 수 있게 해줌

# %%
plt.contour(x,y,z)
plt.xlabel('x')
plt.ylabel('y')
plt.title('결합확률밀도함수 P(x,y)')
plt.show()

# %% [markdown]
# ### 주변확률밀도함수
# - 주변확률밀도 함수는 하나의 변수를 가중평균을 하고 나머지 하나의 변수에 대해서 확률밀도함수를 구하는 것
# - 주변확률밀도함수는 결합확률 밀도 함수를 통해 단일변수의 확률밀도함수를 구하는 것
#
# $${P_X}(x) = ∫{P_{XY}}(x,y)dy$$
# $${P_Y}(y) = ∫{P_{XY}}(x,y)dx$$

# %%
from matplotlib.ticker import NullFormatter
from matplotlib import transforms
from scipy.integrate import simps

mu = [70, 170] # 몸무게, 키
cov = [
    [150, 140],
    [140, 300]
]

x = np.linspace(20, 120, 100)
y = np.linspace(100, 250, 100)

# 2D => 3D
xm, ym = np.meshgrid(x, y)

rv = sp.stats.multivariate_normal(mu, cov)
z = rv.pdf(np.dstack([xm, ym]))

# %%
fx = [simps(z1, y) for z1 in z.T] # x에 대한 주변밀도함수
fy = [simps(z1, x) for z1 in z] # y에 대한 주변밀도함수

left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
bottom_h = left_h = left + width + 0.05

rect1 = [left, bottom, width, height]
rect2 = [left, bottom_h, width, 0.2]
rect3 = [left_h, bottom, 0.2, height]

ax1 = plt.axes(rect1)
ax2 = plt.axes(rect2)
ax3 = plt.axes(rect3)

ax2.xaxis.set_major_formatter(NullFormatter())
ax3.xaxis.set_major_formatter(NullFormatter())

ax1.contour(xm, ym, z)
ax1.set_title('결합확률분포 함수')
ax1.set_xlabel('x')
ax1.set_xlabel('y')

ax2.plot(x, fx)
ax2.set_title('주변확률밀도함수 x(몸무게)')

base = ax3.transData
rot = transforms.Affine2D().rotate_deg(-90)
plt.plot(-y, fy, transform=rot+base)
plt.title('주변확률밀도함수 y(키)')

ax1.set_xlim(38, 102)
ax2.set_xlim(38, 102)
ax3.set_xlim(0, 0.025)

ax1.set_ylim(120, 220)
ax3.set_ylim(120, 220)

plt.show()

# %% [markdown]
# ### 조건부 확률 밀도함수
# 다 변수 확률 변수 중에 하나가 특정한 값일 경우 나머지 확률밀도함수를 조건부 확률 밀도함수
#
# $${P_{X|Y}}(x|y)=\frac{P_{XY}(x,y)}{P_Y(y)}$$
#
# $${P_{Y|X}}(y|x)=\frac{P_{XY}(x,y)}{P_X(x)}$$

# %%
from matplotlib.collections import PolyCollection
from matplotlib import colors as mcolors

# %%
mu = [70, 170] # 몸무게, 키
cov = [
    [150, 140],
    [140, 300]
]

x = np.linspace(20, 120, 100)
y = np.linspace(100, 250, 16)

xm, ym = np.meshgrid(x, y)
rv = sp.stats.multivariate_normal(mu, cov)
z = rv.pdf(np.dstack([xm, ym]))

fig = plt.figure(dpi=150) # 1인치 안에 들어가는
ax = fig.add_subplot(projection = '3d')

xs = np.hstack([0, x, 0])
zs = np.zeros_like(xs)
verts = []

for i, y1 in enumerate(y):
  zs[1:-1] = z[i]
  verts.append(list(zip(x,zs)))

poly = PolyCollection(verts)
poly.set_alpha(0.5)
ax.add_collection3d(poly, zs=y, zdir='y')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlim(20,120)
ax.set_ylim(100, 250)
ax.set_zlim3d(0,0.0007)
ax.view_init(50,-50)
plt.title('결합확률밀도함수의 단면')
plt.show()

# %%
mu = [70, 170] # 몸무게, 키
cov = [
    [150, 140],
    [140, 300]
]

n = 10
x = np.linspace(20, 120, 100)
y = np.linspace(100, 250, 16)

xm, ym = np.meshgrid(x, y)
rv = sp.stats.multivariate_normal(mu, cov)
z = rv.pdf(np.dstack([xm, ym]))

plt.figure(figsize=(8,6))

for i, j in enumerate(range(5, 10)):
  ax = plt.subplot(5, 1, i+1)
  ax.tick_params(labelleft=False)
  plt.plot(x, z[j,:] * 10, label='결합확률밀도함수의 단면')
  density = simps(z[j,:], x)
  plt.plot(x, z[j,:]/density, label='조건부확률밀도함수')
  ax.xaxis.set_ticklabels([])
  plt.ylabel(f'p(x, y={y[j]})', rotation=0, labelpad=30)
  if i == 0:
    plt.legend(loc=2)
plt.xlabel('x')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 독립
# 표본 값이 달라질 때 다른 확률 변수의 조건부 분포가 달라질 때 상관관계가 있다.
# 두 확률변수가 상관관계 아니면 서로 독립
#
# $${P_{XY}}(x,y) = {P_X}(x){P_Y}(y)$$

# %% [markdown]
# ### 조건부 확률분포
# 독립인 X,Y의 조건부 확률밀도함수는 주변확률밀도함수와 같다.
#
# $${P_{X|Y}}(x|y) = \frac{{P_X}(x){P_Y}(y)}{P_Y(y)} = {P_X(x)}$$
# $${P_{Y|X}}(y|x) = \frac{{P_X}(x){P_Y}(y)}{P_X(x)} = {P_Y(y)}$$

# %%
pmf1 = np.array(
    [
     [1, 2, 4, 2, 1],
     [2, 4, 8, 4, 2],
     [4, 8, 16, 8, 4],
     [2, 4, 8, 4, 2],
     [1, 2, 4, 2, 1]
    ]
)
pmf1 = pmf1/pmf1.sum()

# %%
pmf1
# Out:
# array([[0.01, 0.02, 0.04, 0.02, 0.01],
#        [0.02, 0.04, 0.08, 0.04, 0.02],
#        [0.04, 0.08, 0.16, 0.08, 0.04],
#        [0.02, 0.04, 0.08, 0.04, 0.02],
#        [0.01, 0.02, 0.04, 0.02, 0.01]])

# %%
pmf_x = pmf1.sum(axis=0)
pmf_y = pmf1.sum(axis=1)

# %%
pmf_x
# Out:
# array([0.1, 0.2, 0.4, 0.2, 0.1])

# %%
pmf_y
# Out:
# array([0.1, 0.2, 0.4, 0.2, 0.1])

# %%
pmf1x = pmf_x*pmf_y[:, np.newaxis]

# %%
plt.subplot(121)
sns.heatmap(pmf1, annot=True, square=True, cbar = False, xticklabels=pmf_x, yticklabels=pmf_y)
plt.title('독립인 두 확률변수의 결합확률질량 함수')

plt.subplot(122)
sns.heatmap(pmf1x, annot=True, square=True, cbar = False, xticklabels=pmf_x, yticklabels=pmf_y)
plt.title('독립인 두 변수의 주변확률질량함수의 곱')
plt.tight_layout()
plt.show()

# %%
pmf1[0, :]/pmf_y[0]
# Out:
# array([0.1, 0.2, 0.4, 0.2, 0.1])

# %% [markdown]
# 상관관계가 있는 두 확률변수

# %%
pmf2 = np.array([
    [0, 0, 0, 5, 5],
    [0, 5, 5, 5, 5],
    [0, 5, 30, 5, 0],
    [5, 5, 5, 5, 0],
    [5, 5, 0, 0, 0]
])
pmf2 = pmf2/pmf2.sum()

pmf2_x = pmf2.sum(axis=0)
pmf2_y = pmf2.sum(axis=1)
pmf2x = pmf2_x * pmf2_y[:,np.newaxis]

plt.subplot(121)
sns.heatmap(pmf2, annot=True, square=True, cbar = False, xticklabels=pmf2_x.round(2), yticklabels=pmf2_y.round(2))
plt.title('상관관계가 있는 확률변수의 결합확률질량 함수')

plt.subplot(122)
sns.heatmap(pmf2x, annot=True, square=True, cbar = False, xticklabels=pmf2_x.round(2), yticklabels=pmf2_y.round(2))
plt.title('두 변수의 주변확률질량함수의 곱')
plt.tight_layout()
plt.show()

# %%
for i in range(len(pmf1)):
  print(pmf1[i, :]/pmf_y[i])
# Out:
# [0.1 0.2 0.4 0.2 0.1]
# [0.1 0.2 0.4 0.2 0.1]
# [0.1 0.2 0.4 0.2 0.1]
# [0.1 0.2 0.4 0.2 0.1]
# [0.1 0.2 0.4 0.2 0.1]

# %%
for i in range(len(pmf2)):
  print(pmf2[i, :]/pmf2_y[i])
# Out:
# [0.  0.  0.  0.5 0.5]
# [0.   0.25 0.25 0.25 0.25]
# [0.    0.125 0.75  0.125 0.   ]
# [0.25 0.25 0.25 0.25 0.  ]
# [0.5 0.5 0.  0.  0. ]
